# %%
import pandas as pd

# %% [markdown]
# ## Load Data

# %%
product_df = pd.read_csv("../data/raw/product_metadata.csv")
product_df.head()
# Out:
#    product_id                                       product_name  aisle_id  \
# 0           1                         Chocolate Sandwich Cookies        61
# 1           2                                   All-Seasons Salt       104
# 2           3               Robust Golden Unsweetened Oolong Tea        94
# 3           4  Smart Ones Classic Favorites Mini Rigatoni Wit...        38
# 4           5                          Green Chile Anytime Sauce         5
#
#    department_id                       aisle department
# 0             19               cookies cakes     snacks
# 1             13           spices seasonings     pantry
# 2              7                         tea  beverages
# 3              1                frozen meals     frozen
# 4             13  marinades meat preparation     pantry

# %% [markdown]
# #### Select Random Data

# %%
filtered_df = product_df[product_df['aisle_id'] == 94] # aisle is tea.
filtered_df.head()
# Out:
#      product_id                          product_name  aisle_id  \
# 2             3  Robust Golden Unsweetened Oolong Tea        94
# 86           87                Classics Earl Grey Tea        94
# 96           97           Organic Chamomile Lemon Tea        94
# 176         177              Citrus Terere Yerba Mate        94
# 232         233           Chinese Breakfast Black Tea        94
#
#      department_id aisle department
# 2                7   tea  beverages
# 86               7   tea  beverages
# 96               7   tea  beverages
# 176              7   tea  beverages
# 232              7   tea  beverages

# %%
filtered_rows = filtered_df.shape[0]
print(f'Number of rows: {filtered_rows}')
# Out:
# Number of rows: 894

# %%
sample_df = filtered_df.sample(n=50, random_state=42)
sample_df.head()
# Out:
#        product_id                          product_name  aisle_id  \
# 39148       39149         Cinnamon Apple Spice Herb Tea        94
# 23729       23730    Tahitian Vanilla Hazelnut Tea Bags        94
# 28871       28872                 Lemon Flavor Iced Tea        94
# 39705       39706  Unsweetened Organic Ginger Oasis Tea        94
# 1926         1927        Cool Brew Peach Black Iced Tea        94
#
#        department_id aisle department
# 39148              7   tea  beverages
# 23729              7   tea  beverages
# 28871              7   tea  beverages
# 39705              7   tea  beverages
# 1926               7   tea  beverages

# %%
sample_df.to_csv("../data/raw/sample_product_metadata.csv", index=False)

# %%
df = sample_df.copy()

# %% [markdown]
# ## OpenAI Access

# %%
import os
from dotenv import load_dotenv

load_dotenv()
openai_api_key = os.getenv('OPENAI_API_KEY')

# %%
from openai import OpenAI
client = OpenAI()

# %% [markdown]
# ## Create Embedding

# %%
def get_embedding(text, model="text-embedding-3-small"):
    text = text.replace("\n", " ")
    return client.embeddings.create(input=[text], model=model).data[0].embedding

# %%
df['product_embedding'] = df.product_name.apply(lambda x: get_embedding(x, model='text-embedding-3-small'))

# %%
df.to_csv('../data/processed/product_embeddings.csv', index=False)

# %%
embedding_df = pd.read_csv("../data/processed/product_embeddings.csv")
embedding_df.head()
# Out:
#    product_id                          product_name  aisle_id  department_id  \
# 0       39149         Cinnamon Apple Spice Herb Tea        94              7
# 1       23730    Tahitian Vanilla Hazelnut Tea Bags        94              7
# 2       28872                 Lemon Flavor Iced Tea        94              7
# 3       39706  Unsweetened Organic Ginger Oasis Tea        94              7
# 4        1927        Cool Brew Peach Black Iced Tea        94              7
#
#   aisle department                                  product_embedding
# 0   tea  beverages  [-0.018135325983166695, 0.011038893833756447, ...
# 1   tea  beverages  [-0.038035646080970764, -0.024901220574975014,...
# 2   tea  beverages  [-0.0034146751277148724, 0.0018586806254461408...
# 3   tea  beverages  [-0.0067253680899739265, -0.025777382776141167...
# 4   tea  beverages  [0.030188988894224167, -0.013948407024145126, ...

# %%
result = get_embedding("Mix Popcorn	")
print(result)
# Out:
# [-0.028404494747519493, 0.03662276640534401, -0.022751789540052414, -0.044826943427324295, -0.04443224146962166, -0.08063211292028427, 0.013300069607794285, 0.049140479415655136, 0.017451496794819832, -0.009338947013020515, 0.036932893097400665, 0.031491633504629135, 0.03659457340836525, 0.05218533053994179, 0.0019699891563504934, -0.005272099748253822, -0.011530956253409386, -0.006946061737835407, 0.012595243752002716, -0.018424157053232193, 0.009014726616442204, 0.03408539295196533, -0.02007344923913479, 0.01755017228424549, 0.041359201073646545, 0.001356790424324572, -0.05164966359734535, 0.08835700899362564, 0.03211187943816185, 0.0028474978171288967, 0.010198834352195263, -0.03625625744462013, -0.026149051263928413, -0.03431093692779541, -0.026952553540468216, -0.05317208543419838, -0.011989093385636806, 0.01553436927497387, -0.025726156309247017, -1.885960591607727e-05, -0.020186221227049828, -0.015844492241740227, -0.012926512397825718, 0.024697110056877136, 0.062419407069683075, 0.025683864951133728, -0.010424379259347916, -0.01780390925705433, 0.0378914549946785, 0.05599139258265495, -0.06298326700925827, 0.020764179527759552, -0.009585635736584663, 0.02324516698718071, 0.008866713382303715, 0.009987386874854565, -0.03182994946837425, 0.03797603398561478, -0.013321214355528355, -0.02217383123934269, 0.008704603649675846, -0.013405794277787209, 0.02754460647702217, 0.0051276106387376785, -0.02082056552171707, 0.02548651397228241, -0.02445746771991253, 0.007330192252993584, 0.048125531524419785, 0.010071965865790844, -0.062306635081768036, -0.008500203490257263, -0.11006565392017365, -0.031237896531820297, -0.009874614886939526, -0.016817152500152588, 0.0026272395625710487, -0.024979040026664734, 0.014315019361674786, 0.03292948007583618, 0.03433912992477417, 0.016211001202464104, -0.004873873200267553, 0.03394442796707153, 0.03304225206375122, -0.0008550422498956323, -0.06631004810333252, 0.03955484554171562, -0.01898801699280739, -0.015943167731165886, -0.012200540862977505, 0.008859665133059025, 0.0030254663433879614, -0.0026994843501597643, -0.006156656425446272, -0.017930777743458748, 0.043642837554216385, 0.003862447338178754, 0.04654671996831894, 0.051480505615472794, 0.03448009490966797, -0.0060791256837546825, -0.005117038264870644, -0.036876507103443146, 0.039131950587034225, 0.043811995536088943, -0.03715843707323074, 0.02671291120350361, 0.009634973481297493, 0.0031576212495565414, -0.06890380382537842, -0.024993136525154114, -0.0044192601926624775, 0.004091516137123108, 0.014216343872249126, -0.008063211105763912, 0.0731891468167305, -0.055681269615888596, -0.039272915571928024, -0.02227250672876835, -0.020609118044376373, -0.005300292745232582, -0.01769113726913929, -0.031378861516714096, 0.0026413360610604286, 0.02660013921558857, 0.004704714752733707, -0.01499870140105486, 0.005268575623631477, -0.002836925443261862, 0.017254143953323364, 0.005388396326452494, 0.04090811312198639, -0.009867566637694836, 0.01495641190558672, -0.003968171309679747, -0.04775902256369591, -0.0002605654299259186, 0.02087695151567459, 0.056893568485975266, 0.03653818741440773, -0.012630484998226166, 0.0029708424117416143, 0.027234483510255814, -0.02309010550379753, -0.027939310297369957, -0.022455761209130287, -0.017169564962387085, -0.014371405355632305, 0.019467299804091454, -0.015280631370842457, -0.012482471764087677, -0.0746551901102066, 0.0002907408052124083, -0.0418102890253067, -0.05520198494195938, 0.0378914549946785, -0.004672997631132603, -0.009402381256222725, 0.02003115974366665, -7.813658885424957e-05, 0.005747857503592968, 0.018410060554742813, -0.0004920567735098302, 0.0037954889703541994, 0.05057832598686218, 0.001177059719339013, 0.050380975008010864, -0.056837182492017746, 0.018142225220799446, -0.011136253364384174, -0.011382943019270897, -0.006625365931540728, -0.03667915239930153, -0.010318655520677567, -4.757576607516967e-05, -0.04519345611333847, -0.0024721778463572264, -0.03098415955901146, -0.03315502 ...

# %% [markdown]
# ## Create embeddings and add to ChromaDB

# %%
import chromadb

#Initialize ChromaDB
chroma_client = chromadb.PersistentClient(path="../data/chroma_storage")

# %%
# Delete collection
# chroma_client.delete_collection("product_embeddings")

# %%
collection = chroma_client.create_collection(name="product_embeddings")

# %%
cc = chroma_client.get_collection(name="product_embeddings")

# %%
for index, row in df.iterrows():
    response = client.embeddings.create(input=row['product_name'], model='text-embedding-3-small')
    embedding = response.data[0].embedding
    
    # Add document to ChromaDB
    collection.add(
        embeddings=embedding,
        metadatas={'product_name': row['product_name']},
        ids=str(row['product_id'])
    )

# %% [markdown]
# ## Similar Product Recommendation

# %%
def recommend_products(product_name, top_n=3):
    # Get embedding for the input description
    response = client.embeddings.create(input=product_name, model='text-embedding-3-small')
    input_embedding = response.data[0].embedding

    # Query Chromadb for similar embeddings
    results = collection.query(query_embeddings=input_embedding, n_results=top_n)

    # Extract and return recommended products
    recommendations = []
    metadatas = results['metadatas']

    product_names = [item['product_name'] for sublist in metadatas for item in sublist]

    for product_name in product_names:
        recommendations.append({'product_name': product_name})

    return recommendations

# %%
recommendations = recommend_products('Green Tea')
print(recommendations)
# Out:
# [{'product_name': 'Classic Green Tea'}, {'product_name': 'Green Tea with Mint'}, {'product_name': 'Organic Pure Green Tea'}]

# %%
response = client.embeddings.create(input='milk tea', model='text-embedding-3-small')
input_embedding = response.data[0].embedding
results = collection.query(query_embeddings=input_embedding, n_results=3)
print(results)
print(type(results))
# Out:
# {'ids': [['36207', '9844', '5459']], 'distances': [[0.9575251340866089, 1.0038809776306152, 1.0046604871749878]], 'metadatas': [[{'product_name': 'Mint & Honey Green Tea'}, {'product_name': 'Raspberry Iced Tea'}, {'product_name': 'Chamomile Tea'}]], 'embeddings': None, 'documents': [[None, None, None]], 'uris': None, 'data': None, 'included': ['metadatas', 'documents', 'distances']}
# <class 'dict'>

# %%
recommendations = []
metadatas = results['metadatas']

product_names = [item['product_name'] for sublist in metadatas for item in sublist]

for product_name in product_names:
    recommendations.append({'product_name': product_name})

print(recommendations)
# Out:
# ['Mint & Honey Green Tea', 'Raspberry Iced Tea', 'Chamomile Tea']
# [{'product_name': 'Mint & Honey Green Tea'}, {'product_name': 'Raspberry Iced Tea'}, {'product_name': 'Chamomile Tea'}]

# %% [markdown]
# ## Basket Recommendation

# %%
system_prompt = "You are an AI assistant functioning \
as a recommendation system for ecommerce website. \
Be specific and limit your answers to the requested format. \
Keep your answers short and concise."

# %%
def get_user_prompt(ordered_list_of_items):

    prompt=None
    if len(ordered_list_of_items) > 0:
        items = ', '.join(ordered_list_of_items)
        prompt = f"A user bought the following items: {items}. What next 3 items would he/she be likely to purchase next?"
        prompt += "Express your response as a JSON object with a key of 'next_items and a value representing your array of recommended items."
    
    return prompt

# %%
# Retrieve user prompt
user_prompt = get_user_prompt(
    ['bread', 'coffee']
)
print(user_prompt)
# Out:
# A user bought the following items: bread, coffee. What next 3 items would he/she be likely to purchase next?Express your response as a JSON object with a key of 'next_items and a value representing your array of recommended items.

# %%
# Test Prompt
response = client.chat.completions.create(
    model="gpt-4o-mini",
    messages=[
       {'role': 'system', 'content': system_prompt},
       {'role': 'user', 'content': user_prompt} 
    ],
)

message = response.choices[0].message.content
print(message)
# Out:
# ```json
# {
#   "next_items": ["butter", "jam", "milk"]
# }
# ```

# %%
next_items = ['match green tea', 'milk tea']

# %%
def recommend_products(next_items, top_n=5):
    # Get embedding for the input description
    response = client.embeddings.create(input=next_items, model='text-embedding-3-small')
    input_embedding = response.data[0].embedding

    # Query Chromadb for similar embeddings
    results = collection.query(query_embeddings=input_embedding, n_results=top_n)

    # Extract and return recommended products
    recommendations = []
    metadatas = results['metadatas']

    product_names = [item['product_name'] for sublist in metadatas for item in sublist]

    for product_name in product_names:
        recommendations.append({'product_name': product_name})

    return recommendations

# %%
next_items = ['match green tea', 'milk tea']
recommendations = recommend_products(next_items)
print(recommendations)
# Out:
# [{'product_name': 'Classic Green Tea'}, {'product_name': 'Organic Pure Green Tea'}, {'product_name': 'China Green Tips Green Tea'}, {'product_name': 'Green Tea with Mint'}, {'product_name': 'Mint & Honey Green Tea'}]
